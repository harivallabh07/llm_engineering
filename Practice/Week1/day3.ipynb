# %% [markdown]
# <h1>Running Ollama Loacally with OpenAI compactable endpoints.</h1>

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
import requests

# %%
requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
ollama_base_url = "http://localhost:11434/v1"
ollama=OpenAI(base_url=ollama_base_url,api_key='local_api_key')

# %%
message=input()
messages=[{'role':'user','content':message}]
messages

response=ollama.chat.completions.create(model='llama3.2',messages=messages)
print(response.choices[0].message.content)
# Out:
# I don't have any information about your name. I'm a text-based AI assistant and we've just started our conversation, so I don't have any prior knowledge or context about you. Would you like to share your name with me now?
